# %%
import requests
import json
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display, Markdown

# %%
tipos = []
quantTipos = []
anos = []
quantAno = []
projZero = 0
acimaTeto = 0

totalUrl = 'http://api.salic.cultura.gov.br/v1/projetos/?format=json&'
res = requests.get(totalUrl)
res = json.loads(res.content.decode('utf-8'))
tot=res['total']
tot -= 2

carnaval = 0
totCarnaval = 0

url = 'http://api.salic.cultura.gov.br/v1/projetos/?offset='
url2 = '&format=json&'
totalAprovado = 0
totalSolicitado = 0

# %%
for x in range(0,tot,100):
    print(x)
    res = requests.get(url+str(x)+url2)
    res = json.loads(res.content.decode('utf-8'))
    proj = res['_embedded']['projetos']
    for d in range(len(proj)):
        nome = res['_embedded']['projetos'][d]['nome']
        projeto = res['_embedded']['projetos'][d]['area']
        ano = res['_embedded']['projetos'][d]['ano_projeto']
        cgccpf = res['_embedded']['projetos'][d]['cgccpf']
       
        #Verifica valores solicitados e aprovados de cada projeto   
        valorAprovado = float(res['_embedded']['projetos'][d]['valor_aprovado'])
        valorSolicitado = float(res['_embedded']['projetos'][d]['valor_proposta'])
        ano = res['_embedded']['projetos'][d]['ano_projeto']
        
        #Quantidade de projetos com valor solicitado igual a 0
        if(valorSolicitado>1):
            projZero += 1
            
        if((len(cgccpf)>=13 and valorAprovado>10000000) or (len(cgccpf)==11 and valorAprovado>700000)):
            acimaTeto += 1
            print('Projeto acima do teto:')
            print("------Nome: "+nome)
            print("------CPF ou CNPJ: ",cgccpf)
            print("------Valor aprovado: ",valorAprovado)
        
        #Separa e quantifica projetos de ocordo com os tipos
        if(projeto not in tipos):
            tipos.append(projeto)
            quantTipos.append(1)
        else:
            z = tipos.index(projeto)
            quantTipos[z] += 1
            
        if(ano not in anos):
            anos.append(ano)
            quantAno.append(valorAprovado)
        else:
            i = anos.index(ano)
            quantAno[i] += valorAprovado
       

        #Soma total repassado para carnaval de 2019
        if(('carnaval' in nome.lower() or 'carnaval' in str(projeto).lower()) and ('2019' in nome.lower()) and (int(ano)>=18)):
            
            carnaval += 1
            totCarnaval += valorAprovado
        
        #Imprime projetos a a cada 2000 resultados obtidos
        if(x%2000==0):
            #Exibe resultados
            print("ID: ",d+(x))
            print("Nome do projeto: ",nome)
            print("Área do projeto: ",projeto)


            print("Total Solicitado: %.2f" %valorSolicitado)
            print("Total Aprovado: %.2f" %valorAprovado)

        totalSolicitado+=float(valorSolicitado)            
        totalAprovado+=float(valorAprovado)
# Out:
# 0
# ID:  0
# Nome do projeto:  indaiá
# Área do projeto:  Artes Visuais
# Total Solicitado: 370872.70
# Total Aprovado: 0.00
# ID:  1
# Nome do projeto:  A[R]MAR em Belo Horizonte
# Área do projeto:  Artes Cênicas
# Total Solicitado: 358753.73
# Total Aprovado: 0.00
# ID:  2
# Nome do projeto:  Semana Nacional da Imigração Chinesa no Brasil
# Área do projeto:  Artes Cênicas
# Total Solicitado: 4291887.75
# Total Aprovado: 0.00
# ID:  3
# Nome do projeto:  FestArtGym
# Área do projeto:  Artes Cênicas
# Total Solicitado: 540749.00
# Total Aprovado: 0.00
# ID:  4
# Nome do projeto:  Somos Mães: do laço ao abraço
# Área do projeto:  Artes Visuais
# Total Solicitado: 1183611.83
# Total Aprovado: 0.00
# ID:  5
# Nome do projeto:  Festival Crise de Riso
# Área do projeto:  Artes Cênicas
# Total Solicitado: 358284.85
# Total Aprovado: 0.00
# ID:  6
# Nome do projeto:  FLORES DO CEARÁ E SUAS INFLUÊNCIAS NA CULTURA
# Área do projeto:  Humanidades
# Total Solicitado: 372672.05
# Total Aprovado: 0.00
# ID:  7
# Nome do projeto:  Escola de Cultura SESI: Formação e aprimoramento de crianças e jovens de Pirapora
# Área do projeto:  Música
# Total Solicitado: 454504.48
# Total Aprovado: 0.00
# ID:  8
# Nome do projeto:  PROJETO “Musicando com a  ABEC” - Marechal cândido Rondon - PR
# Área do projeto:  Música
# Total Solicitado: 268668.40
# Total Aprovado: 0.00
# ID:  9
# Nome do projeto:  III MOSTRA DE DANÇAS DE TEUTÔNIA
# Área do projeto:  Artes Cênicas
# Total Solicitado: 227606.50
# Total Aprovado: 0.00
# ID:  10
# Nome do projeto:  Concertos Percussivos Didáticos nas escolas estaduais
# Área do projeto:  Música
# Total Solicitado: 57558.60
# Total Aprovado: 0.00
# ID:  11
# Nome do projeto:  MURDER BALLAD, O ÚLTIMO SOM  (título provisório)
# Área do projeto:  Artes Cênicas
# Total Solicitado: 722675.25
# Total Aprovado: 0.00
# ID:  12
# Nome do projeto:  Madeira - Festival de Música de Rondônia
# Área do projeto:  Música
# Total Solicitado: 915094.13
# Total Aprovado: 0.00
# ID:  13
# Nome do projeto:  Música na Escola
# Área do projeto:  Música
# Total Solicitado: 741802.05
# Total Aprovado: 0.00
# ID:  14
# Nome do projeto:  Fábrica de Músicos
# Área do projeto:  Música
# Total Solicitado: 406453.70
# Total Aprovado: 0.00
# ID:  15
# Nome do projeto:  Edição do livro História da Música Paulista
# Área do projeto:  Humanidades
# Total Solicitado: 541206.28
# Total Aprovado: 0.00
# ID:  16
# Nome do projeto:  TransformAção
# Área do projeto:  Artes Cênicas
# Total Solicitado: 710721.00
# Total Aprovado: 0.00
# ID:  17
# Nome do projeto:  Trilogia das Placas Tectônicas
# Área do projeto:  Artes Cênicas
# Total Solicitado: 711306.75
# Total Aprovado: 0.00
# ID:  18
# Nome do projeto:  Cultura de Rua
# Área do projeto:  Artes Cênicas
# Total Solicitado: 233508.00
# Total Aprovado: 0.00
# ID:  19
# Nome do projeto:  Macbeth
# Área do projeto:  Artes Cênicas
# Total Solicitado: 723008.00
# Total Aprovado: 0.00
# ID:  20
# Nome do projeto:  Liga das Escolas de Samba de Niterói (LESNIT)
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1488933.20
# Total Aprovado: 0.00
# ID:  21
# Nome do projeto:  Olhar e Cuidar (Título provisório)
# Área do projeto:  Humanidades
# Total Solicitado: 528974.82
# Total Aprovado: 0.00
# ID:  22
# Nome do projeto:  Restauração da  Catedral Metropolitana de Ribeirão Preto - SP
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 14836221.12
# Total Aprovado: 0.00
# ID:  23
# Nome do projeto:  O QUEBRA NOZES CAPIXABA
# Área do projeto:  Artes Cênicas
# Total Solicitado: 230940.05
# Total Aprovado: 0.00
# ID:  24
# Nome do projeto:  ESPETÁCULO FAHRENHEIT 451
# Área do projeto:  Artes Cênicas
# Total Solicitado: 670078.64
# Total Aprovado: 0.00
# ID:  25
# Nome do projeto:  PROJETO NÚCLEO DE DIFUSÃO DA MÚSICA SINFÔNICA
# Área do projeto:  Música
# Total Solicitado: 2299419.59
# Total Aprovado: 0.00
# ID:  26
# Nome do projeto:  BRIGADA MIRIM 30 ANOS
# Área do projeto:  Humanidades
# Total Solicitado: 236223.02
# Total Aprovado: 0.00
# ID:  27
# Nome do projeto:  Chimango - Circulação de opera
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1159326.56
# Total Aprovado: 0.00
# ID:  28
# Nome do projeto:  TEMPORADA 2019  DE CONCERTOS  – THEATRO MUNICIPAL DO RJ
# Área do projeto:  Música
# Total Solicitado: 2606001.00
# Total Aprovado: 0.00
# ID:  29
# Nome do projeto:   ORQUESTRA NOS BAIRROS
# Área do projeto:  Música
# Total Solicitado: 457262.40
# Total Aprovado: 0.00
# ID:  30
# Nome do projeto:  Poesias - Coletânia
# Área do projeto:  Humanidades
# Total Solicitado: 227799.00
# Total Aprovado: 0.00
# ID:  31
# Nome do projeto:  Orquestra e Coral Dikaion
# Área do projeto:  Música
# Total Solicitado: 291934.50
# Total Aprovado: 0.00
# ID:  32
# Nome do projeto:  Arte em Dança
# Área do projeto:  Artes Cênicas
# Total Solicitado: 578357.00
# Total Aprovado: 0.00
# ID:  33
# Nome do projeto:  MARINHA BRASILEIRA A SERVIÇO DA PÁTRIA - Superação através da Arte (título provisório)
# Área do projeto:  Humanidades
# Total Solicitado: 592715.75
# Total Aprovado: 0.00
# ID:  34
# Nome do projeto:  Projeto Villa Lobos: O Brasil e suas histórias
# Área do projeto:  Música
# Total Solicitado: 395603.07
# Total Aprovado: 0.00
# ID:  35
# Nome do projeto:  “INVERNADA DO CTG NOVA QUERÊNCIA - PARTICIPAÇÃO EM EVENTOS NACIONAIS DE TRADIÇÃO GAÚCHA”
# Área do projeto:  Artes Cênicas
# Total Solicitado: 762484.14
# Total Aprovado: 0.00
# ID:  36
# Nome do projeto:  ARQUITEXTURA MULTI-CULTURAL
# Área do projeto:  Humanidades
# Total Solicitado: 1499991.80
# Total Aprovado: 0.00
# ID:  37
# Nome do projeto:  Café com história - memória, (re)conhecimento e identidade
# Área do projeto:  Museus e Memória
# Total Solicitado: 858033.75
# Total Aprovado: 0.00
# ID:  38
# Nome do projeto:  Showlivreday  Festival de Música Brasileira
# Área do projeto:  Música
# Total Solicitado: 4185211.99
# Total Aprovado: 0.00
# ID:  39
# Nome do projeto:  FILHOS DO MAR - LIVRO DE ARTE
# Área do projeto:  Humanidades
# Total Solicitado: 449843.55
# Total Aprovado: 0.00
# ID:  40
# Nome do projeto:  A BUSCA DA ESTRELA
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1254710.60
# Total Aprovado: 0.00
# ID:  41
# Nome do projeto:  São João Tradição em Santa Luzia 2019 | São João da Rua de Baixo
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 203775.97
# Total Aprovado: 0.00
# ID:  42
# Nome do projeto:  Revista Diáspora
# Área do projeto:  Humanidades
# Total Solicitado: 872277.02
# Total Aprovado: 0.00
# ID:  43
# Nome do projeto:  King´s Brazil Institute
# Área do projeto:  Música
# Total Solicitado: 4668566.94
# Total Aprovado: 0.00
# ID:  44
# Nome do projeto:  Educar com Cultura - Camaçari
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1020156.16
# Total Aprovado: 0.00
# ID:  45
# Nome do projeto:  Coleção Biscoito – Livros para crianças de Zero a Seis Anos
# Área do projeto:  Humanidades
# Total Solicitado: 261489.38
# Total Aprovado: 0.00
# ID:  46
# Nome do projeto:  Exposição Eclipse19 - 100 anos da Teoria de Relatividade (nome provisório)
# Área do projeto:  Museus e Memória
# Total Solicitado: 1284161.45
# Total Aprovado: 0.00
# ID:  47
# Nome do projeto:  MÚSICA PARATODOS
# Área do projeto:  Música
# Total Solicitado: 2548086.00
# Total Aprovado: 0.00
# ID:  48
# Nome do projeto:  Anaïs
# Área do projeto:  Artes Cênicas
# Total Solicitado: 600125.63
# Total Aprovado: 0.00
# ID:  49
# Nome do projeto:  Retrospectiva Helena Wong
# Área do projeto:  Artes Visuais
# Total Solicitado: 1979101.50
# Total Aprovado: 0.00
# ID:  50
# Nome do projeto:  Raízes da Nossa Terra - 1ª Edição
# Área do projeto:  Música
# Total Solicitado: 732058.80
# Total Aprovado: 0.00
# ID:  51
# Nome do projeto:  Mostra Yutaka Toyota SP-Arte
# Área do projeto:  Artes Visuais
# Total Solicitado: 357173.85
# Total Aprovado: 0.00
# ID:  52
# Nome do projeto:  Festival Cidade do Artista (nome provisório)
# Área do projeto:  Artes Visuais
# Total Solicitado: 5199776.13
# Total Aprovado: 0.00
# ID:  53
# Nome do projeto:  Música é Saúde
# Área do projeto:  Música
# Total Solicitado: 169824.60
# Total Aprovado: 0.00
# ID:  54
# Nome do projeto:  PIRA – Parque Interativo Rua e Arte
# Área do projeto:  Artes Visuais
# Total Solicitado: 5182260.00
# Total Aprovado: 0.00
# ID:  55
# Nome do projeto:  Mais Vida
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1532554.75
# Total Aprovado: 0.00
# ID:  56
# Nome do projeto:  Hop (viva o hip hop)
# Área do projeto:  Artes Cênicas
# Total Solicitado: 201143.25
# Total Aprovado: 0.00
# ID:  57
# Nome do projeto:  Amazônia I
# Área do projeto:  Humanidades
# Total Solicitado: 1031937.50
# Total Aprovado: 0.00
# ID:  58
# Nome do projeto:  Festival do Tucum
# Área do projeto:  Música
# Total Solicitado: 146301.75
# Total Aprovado: 0.00
# ID:  59
# Nome do projeto:  SUB
# Área do projeto:  Artes Visuais
# Total Solicitado: 4497675.00
# Total Aprovado: 0.00
# ID:  60
# Nome do projeto:  Mara Rúbia a Loura Infernal
# Área do projeto:  Artes Cênicas
# Total Solicitado: 2102808.75
# Total Aprovado: 0.00
# ID:  61
# Nome do projeto:  MEMÓRIAS DE UMA MANICURE
# Área do projeto:  Artes Cênicas
# Total Solicitado: 556644.82
# Total Aprovado: 0.00
# ID:  62
# Nome do projeto:  Projeto Esse Boi é Catarina
# Área do projeto:  Música
# Total Solicitado: 115697.12
# Total Aprovado: 0.00
# ID:  63
# Nome do projeto:  Caruaru Por Paixão
# Área do projeto:  Artes Cênicas
# Total Solicitado: 366456.00
# Total Aprovado: 0.00
# ID:  64
# Nome do projeto:  Exposição 17 anos  Lavage de Madaleine Paris
# Área do projeto:  Artes Visuais
# Total Solicitado: 261325.00
# Total Aprovado: 0.00
# ID:  65
# Nome do projeto:  Circulação - Malala, a menina que queria ir para a escola
# Área do projeto:  Artes Cênicas
# Total Solicitado: 681169.50
# Total Aprovado: 0.00
# ID:  66
# Nome do projeto:  RESTAURAÇÃO DE UM BONDE HISTÓRICO E CRIAÇÃO DE ESPAÇO CULTURAL
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 276237.50
# Total Aprovado: 0.00
# ID:  67
# Nome do projeto:  FESTIVAL DE CULTURA BAIANA - Do Tradicional ao Contemporâneo
# Área do projeto:  Música
# Total Solicitado: 7795117.52
# Total Aprovado: 0.00
# ID:  68
# Nome do projeto:  DANÇAS TRADICIONAIS E A IDENTIDADE CULTURAL DO SUL DO BRASIL
# Área do projeto:  Artes Cênicas
# Total Solicitado: 258852.00
# Total Aprovado: 0.00
# ID:  69
# Nome do projeto:  I Bienal do Lixo
# Área do projeto:  Artes Visuais
# Total Solicitado: 2906596.03
# Total Aprovado: 0.00
# ID:  70
# Nome do projeto:  Aprimoramento e manutenção do Centro de Memória - Centro Cultural Minas Tênis
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 501826.11
# Total Aprovado: 0.00
# ID:  71
# Nome do projeto:  Tempestades de Silêncio
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1920925.00
# Total Aprovado: 0.00
# ID:  72
# Nome do projeto:  Destemidos
# Área do projeto:  Humanidades
# Total Solicitado: 988473.80
# Total Aprovado: 0.00
# ID:  73
# Nome do projeto:  AILA ALBUM AUDIOVISUAL
# Área do projeto:  Música
# Total Solicitado: 424644.00
# Total Aprovado: 0.00
# ID:  74
# Nome do projeto:  Pintura Técnica e Artística
# Área do projeto:  Humanidades
# Total Solicitado: 384763.50
# Total Aprovado: 0.00
# ID:  75
# Nome do projeto:  OUROBOROS - circulação Rio de Janeiro
# Área do projeto:  Artes Cênicas
# Total Solicitado: 149672.38
# Total Aprovado: 0.00
# ID:  76
# Nome do projeto:  12º Festa do Pinhão 2019 -Atividades Culturais
# Área do projeto:  Artes Cênicas
# Total Solicitado: 507292.50
# Total Aprovado: 0.00
# ID:  77
# Nome do projeto:  1º FESTIVAL DE DANÇA DO CLUBE DE GUAXUPÉ/MG
# Área do projeto:  Artes Cênicas
# Total Solicitado: 113173.51
# Total Aprovado: 0.00
# ID:  78
# Nome do projeto:  Cooperando
# Área do projeto:  Artes Cênicas
# Total Solicitado: 378229.50
# Total Aprovado: 0.00
# ID:  79
# Nome do projeto:  Mostra de performance arte Verbo 2019 (15ª edição)&#8232;
# Área do projeto:  Artes Visuais
# Total Solicitado: 468618.16
# Total Aprovado: 0.00
# ID:  80
# Nome do projeto:   #Partiu Enem
# Área do projeto:  Artes Cênicas
# Total Solicitado: 86150.74
# Total Aprovado: 0.00
# ID:  81
# Nome do projeto:  4º Sonido - Música Instrumental & Experimental
# Área do projeto:  Música
# Total Solicitado: 465036.00
# Total Aprovado: 0.00
# ID:  82
# Nome do projeto:  Festa das Luzes do Rio
# Área do projeto:  Artes Visuais
# Total Solicitado: 4688266.08
# Total Aprovado: 0.00
# ID:  83
# Nome do projeto:  VII Festival de Teatro Tecendo o Riso
# Área do projeto:  Artes Cênicas
# Total Solicitado: 217184.00
# Total Aprovado: 0.00
# ID:  84
# Nome do projeto:  Brasil Cultural e Viola Caipira
# Área do projeto:  Música
# Total Solicitado: 1489752.00
# Total Aprovado: 0.00
# ID:  85
# Nome do projeto:  Modernas Ferramentas Científicas de Exploração 2
# Área do projeto:  Música
# Total Solicitado: 188768.14
# Total Aprovado: 0.00
# ID:  86
# Nome do projeto:  Gala Ballet - Tour 2019
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1782602.50
# Total Aprovado: 0.00
# ID:  87
# Nome do projeto:  Desfiles Oktoberfest 2019
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1840828.65
# Total Aprovado: 0.00
# ID:  88
# Nome do projeto:  2º Festival Gastronômico de Paraopeba
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 57368.00
# Total Aprovado: 0.00
# ID:  89
# Nome do projeto:  BANDA MARCIAL SANTA MARIA
# Área do projeto:  Música
# Total Solicitado: 289580.00
# Total Aprovado: 0.00
# ID:  90
# Nome do projeto:  Criação da Biblioteca Nilson Thomé de Ciências da Saúde no Campus Curitibanos da Universidade Federal de Santa Catarina
# Área do projeto:  Humanidades
# Total Solicitado: 1590062.39
# Total Aprovado: 0.00
# ID:  91
# Nome do projeto:  Concerto de Hélène Grimaud
# Área do projeto:  Música
# Total Solicitado: 541051.50
# Total Aprovado: 0.00
# ID:  92
# Nome do projeto:  Sintonias Canada Brasil Music Fest 2019
# Área do projeto:  Música
# Total Solicitado: 625288.95
# Total Aprovado: 0.00
# ID:  93
# Nome do projeto:  XIX Encontro de Culturas Tradicionais da Chapada dos Veadeiros
# Área do projeto:  Artes Cênicas
# Total Solicitado: 326496.50
# Total Aprovado: 0.00
# ID:  94
# Nome do projeto:  CÃO DE CAÇA (SLEUTH) - título provisório
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1000926.85
# Total Aprovado: 0.00
# ID:  95
# Nome do projeto:  Música Social
# Área do projeto:  Música
# Total Solicitado: 230889.73
# Total Aprovado: 0.00
# ID:  96
# Nome do projeto:  Olhares Culturais
# Área do projeto:  Música
# Total Solicitado: 374616.00
# Total Aprovado: 0.00
# ID:  97
# Nome do projeto:  MACUCO MUSIC FESTIVAL – Festival de Música de São Carlos/SC
# Área do projeto:  Música
# Total Solicitado: 537525.08
# Total Aprovado: 0.00
# ID:  98
# Nome do projeto:  Rock + Humor
# Área do projeto:  Música
# Total Solicitado: 771444.08
# Total Aprovado: 0.00
# ID:  99
# Nome do projeto:  Liga da Mata – O Renascimento da Alma – O Musical
# Área do projeto:  Artes Cênicas
# Total Solicitado: 4611617.07
# Total Aprovado: 0.00
# 100
# Projeto acima do teto:
# ------Nome: Cidades Culturais
# ------CPF ou CNPJ:  ***844918**
# ------Valor aprovado:  783337.5
# Projeto acima do teto:
# ------Nome: Livrovoz - Audiolivros para todos
# ------CPF ou CNPJ:  ***853776**
# ------Valor aprovado:  728036.1
# Projeto acima do teto:
# ------Nome: Vovô faz 70 anos (... e comemora do seu jeito)
# ------CPF ou CNPJ:  ***560798**
# ------Valor aprovado:  745173.0
# 200
# Projeto acima do teto:
# ------Nome: Projeto Maná, Arte & Dança
# ------CPF ou CNPJ:  ***059108**
# ------Valor aprovado:  725481.9
# Projeto acima do teto:
# ------Nome: Jovem Mágico Gabriel Montenegro
# ------CPF ou CNPJ:  ***517567**
# ------Valor aprovado:  1311403.65
# Projeto acima do teto:
# ------Nome:  Festival Receita Cultural
# ------CPF ou CNPJ:  ***257986**
# ------Valor aprovado:  700603.2
# Projeto acima do teto:
# ------Nome: Chocopáscoa - Artes e reflexão
# ------CPF ou CNPJ:  ***454396**
# ------Valor aprovado:  924412.5
# Projeto acima do teto:
# ------Nome: Lona Protetora
# ------CPF ou CNPJ:  ***351888**
# ------Valor aprovado:  711409.52
# Projeto acima do teto:
# ------Nome: Cutículas
# ------CPF ou CNPJ:  ***277071**
# ------Valor aprovado:  799656.0
# Projeto acima do teto:
# ------Nome: Museu do Volei de Maringá
# ------CPF ou CNPJ:  04571078000117
# ------Valor aprovado:  11024312.32
# 300
# Projeto acima do teto:
# ------Nome: Projeto de Conservação e Restauração da Basílica de Nazaré e Requalificação da Cripta
# ------CPF ou CNPJ:  04746442000132
# ------Valor aprovado:  13558675.1
# Projeto acima do teto:
# ------Nome: MUSEU DO IPIRANGA - OBRA CIVIL DO ANEXO
# ------CPF ou CNPJ:  68314830000127
# ------Valor aprovado:  50916988.01
# 400
# Projeto acima do teto:
# ------Nome: Samba Mais Rio
# ------CPF ou CNPJ:  07113090000176
# ------Valor aprovado:  12349950.0
# Projeto acima do teto:
# ------Nome: FICC 2019 - FESTIVAL INTERNACIONAL DE CERVEJA E CULTURA
# ------CPF ou CNPJ:  ***560996**
# ------Valor aprovado:  854302.35
# Projeto acima do teto:
# ------Nome: OKTOBERFEST FLORIANÓPOLIS SC
# ------CPF ou CNPJ:  ***836859**
# ------Valor aprovado:  1080783.0
# Projeto acima do teto:
# ------Nome: Produção do CD/DVD Junior Costa - O Começo
# ------CPF ou CNPJ:  ***345691**
# ------Valor aprovado:  705922.48
# Projeto acima do teto:
# ------Nome: REQUALIFICAÇÃO, RESTAURO E CONSERVAÇÃO DOS BLOCOS 20 e 21  COMPLEXO FEPASA
# ------CPF ou CNPJ:  54690367000103
# ------Valor aprovado:  32011168.05
# Projeto acima do teto:
# ------Nome: FOTOGRAFIAS DO ACERVO DO MUSEU NACIONAL DA UFRJ
# ------CPF ou CNPJ:  ***146157**
# ------Valor aprovado:  946743.94
# Projeto acima do teto:
# ------Nome: Levante das Ruas São Francisco e Riachuelo
# ------CPF ou CNPJ:  ***059529**
# ------Valor aprovado:  701662.5
# Projeto acima do teto:
# ------Nome: PAIXÃO DE CRISTO DO RECIFE - HOMENAGEM A JOSÉ PIMENTEL
# ------CPF ou CNPJ:  ***264394**
# ------Valor aprovado:  2163538.05
# 500
# Projeto acima do teto:
# ------Nome: Babi Souza & Planeta Banana
# ------CPF ou CNPJ:  ***795627**
# ------Valor aprovado:  754952.0
# Projeto acima do teto:
# ------Nome: Taubaté Jazz Orchestra
# ------CPF ou CNPJ:  ***544858**
# ------Valor aprovado:  1499234.42
# Projeto acima do teto:
# ------Nome: Projeto Seis e Meia na Paraíba - Ano 2019
# ------CPF ou CNPJ:  ***391814**
# ------Valor aprovado:  1111817.25
# Projeto acima do teto:
# ------Nome: ÔDA + FEIRA NA ROSENBAUM
# ------CPF ou CNPJ:  ***426549**
# ------Valor aprovado:  707535.0
# Projeto acima do teto:
# ------Nome: Aroma Jazz na praça
# ------CPF ou CNPJ:  ***276729**
# ------Valor aprovado:  799156.05
# 600
# Projeto acima do teto:
# ------Nome: DELES E DELAS / O TESTA VERDE -  Literatura e musica na obra de Geraldo Vilar
# ------CPF ou CNPJ:  ***159196**
# ------Valor aprovado:  1242587.5
# Projeto acima do teto:
# ------Nome: Space Adventure, 50 anos do Homem na Lua
# ------CPF ou CNPJ:  27736004000199
# ------Valor aprovado:  22432086.0
# Projeto acima do teto:
# ------Nome: DONNA SUMMER MUSICAL
# ------CPF ou CNPJ:  04320351000130
# ------Valor aprovado:  14723439.0
# Projeto acima do teto:
# ------Nome: CARNAVAL DE RUA ITALEGRIA
# ------CPF ou CNPJ:  ***674859**
# ------Valor aprovado:  993435.3
# Projeto acima do teto:
# ------Nome: Cinema na Artes
# ------CPF ou CNPJ:  67568774000194
# ------Valor aprovado:  11158520.53
# Projeto acima do teto:
# ------Nome: NOS TEMPOS DA JOVEM GUARDA
# ------CPF ou CNPJ:  ***996758**
# ------Valor aprovado:  934510.5
# Projeto acima do teto:
# ------Nome: Samara Trajano
# ------CPF ou CNPJ:  ***533346**
# ------Valor aprovado:  1057468.5
# Projeto acima do teto:
# ------Nome: PRODUÇÃO DE CD E DVD LOOK TO ME e FESTIVAL DE MÚSICA SOLIDÁRIA
# ------CPF ou CNPJ:  ***666308**
# ------Valor aprovado:  993752.32
# Projeto acima do teto:
# ------Nome: Sollo Santanna - Você está em tudo
# ------CPF ou CNPJ:  ***993741**
# ------Valor aprovado:  941638.5
# 700
# Projeto acima do teto:
# ------Nome: TURNE BEHORT SHOW DE DIVULGAÇÃO DO CD OITO CANTOS .
# ------CPF ou CNPJ:  ***614049**
# ------Valor aprovado:  855762.43
# 800
# Projeto acima do teto:
# ------Nome: Não é Água Não... (MONDOCANA)
# ------CPF ou CNPJ:  ***560798**
# ------Valor aprovado:  752895.0
# Projeto acima do teto:
# ------Nome: Aprendendo com Cultura
# ------CPF ou CNPJ:  ***611159**
# ------Valor aprovado:  785866.92
# Projeto acima do teto:
# ------Nome: 1° Festival Cultural de Cinema e Arte Estudantil - Coletando Vidas
# ------CPF ou CNPJ:  ***640527**
# ------Valor aprovado:  1251483.75
# 900
# Projeto acima do teto:
# ------Nome: VALORES DO SUL
# ------CPF ou CNPJ:  ***841069**
# ------Valor aprovado:  1091920.5
# Projeto acima do teto:
# ------Nome: MARIAS
# ------CPF ou CNPJ:  ***682828**
# ------Valor aprovado:  1491672.59
# 1000
# Projeto acima do teto:
# ------Nome: Bate-Papo Literário Online
# ------CPF ou CNPJ:  ***184767**
# ------Valor aprovado:  782595.0
# Projeto acima do teto:
# ------Nome: Governança do Museu Sacro Franciscano e Restauração artística e arquitetônica da Igreja de São Francisco da Penitência e acervo memorial
# ------CPF ou CNPJ:  14721347000138
# ------Valor aprovado:  100513461.31
# Projeto acima do teto:
# ------Nome: Festival Tião Carreiro
# ------CPF ou CNPJ:  ***029838**
# ------Valor aprovado:  1473491.25
# 1100
# Projeto acima do teto:
# ------Nome: Histórias do Brasil na boca do povo
# ------CPF ou CNPJ:  ***237207**
# ------Valor aprovado:  1029315.13
# Projeto acima do teto:
# ------Nome: SOMETHING ROTTEN
# ------CPF ou CNPJ:  13779600000141
# ------Valor aprovado:  14729456.0
# Projeto acima do teto:
# ------Nome:  Construção do Museu Arquidiocesano de Belo Horizonte – Fase 1- Estruturas, Instalações e Acabamentos.
# ------CPF ou CNPJ:  17505249000151
# ------Valor aprovado:  115888128.99
# Projeto acima do teto:
# ------Nome: DIVERSIDADE: IDENTIDADES E CIDADANIAS
# ------CPF ou CNPJ:  ***036589**
# ------Valor aprovado:  1496140.8
# Projeto acima do teto:
# ------Nome: Jornada da Soja
# ------CPF ou CNPJ:  ***218549**
# ------Valor aprovado:  810810.0
# Projeto acima do teto:
# ------Nome: Marcelo Zion
# ------CPF ou CNPJ:  ***496028**
# ------Valor aprovado:  1129639.5
# Projeto acima do teto:
# ------Nome: CULTURA FEST
# ------CPF ou CNPJ:  ***168858**
# ------Valor aprovado:  783301.13
# Projeto acima do teto:
# ------Nome: TERAPEUTA NADA CONVENCIONAL –UM SHOW DE HUMOR
# ------CPF ou CNPJ:  ***462476**
# ------Valor aprovado:  1146999.15
# 1200
# Projeto acima do teto:
# ------Nome: Musical Minha Vida Sertaneja
# ------CPF ou CNPJ:  ***332208**
# ------Valor aprovado:  1380233.25
# Projeto acima do teto:
# ------Nome:  BESAME MUCHO  - Uma História de Amor e Bolero
# ------CPF ou CNPJ:  ***562817**
# ------Valor aprovado:  1191911.49
# 1300
# Projeto acima do teto:
# ------Nome: BEBA DO QUADRADO - FEIRA DE CERVEJAS ARTESANAIS DO DF / TEMPORADA 2019
# ------CPF ou CNPJ:  ***458666**
# ------Valor aprovado:  998418.96
# Projeto acima do teto:
# ------Nome: Circo Reder – Nome Provisório
# ------CPF ou CNPJ:  01765337000152
# ------Valor aprovado:  15446445.0
# Projeto acima do teto:
# ------Nome: MUSEU DA INDUSTRIA DE MATÃO
# ------CPF ou CNPJ:  05313990000131
# ------Valor aprovado:  12521675.34
# 1400
# Projeto acima do teto:
# ------Nome: É TUDO UM JOGO
# ------CPF ou CNPJ:  ***851687**
# ------Valor aprovado:  797036.63
# Projeto acima do teto:
# ------Nome: A Mulher no Século das Luzes: Os Primórdios da Revolução Feminina
# ------CPF ou CNPJ:  ***516037**
# ------Valor aprovado:  931820.84
# Projeto acima do teto:
# ------Nome: Centro Cultural Vila Guilhermina
# ------CPF ou CNPJ:  ***739369**
# ------Valor aprovado:  1501511.83
# Projeto acima do teto:
# ------Nome: Eu Vivo Música - São Luís
# ------CPF ou CNPJ:  ***858023**
# ------Valor aprovado:  754545.31
# Projeto acima do teto:
# ------Nome: Exposição Fla Memória - ANO I
# ------CPF ou CNPJ:  31814133000125
# ------Valor aprovado:  17110923.74
# Projeto acima do teto:
# ------Nome: Arte por toda Parte
# ------CPF ou CNPJ:  ***981429**
# ------Valor aprovado:  1424958.06
# 1500
# Projeto acima do teto:
# ------Nome: BENDITA
# ------CPF ou CNPJ:  ***848057**
# ------Valor aprovado:  1333689.5
# Projeto acima do teto:
# ------Nome: Formando Leitores, Mudando Histórias
# ------CPF ou CNPJ:  ***952987**
# ------Valor aprovado:  849197.25
# 1600
# Projeto acima do teto:
# ------Nome: Turnê e DVD Théo Mello
# ------CPF ou CNPJ:  ***324726**
# ------Valor aprovado:  883129.5
# Projeto acima do teto:
# ------Nome: Circuito Cultural Sul
# ------CPF ou CNPJ:  ***748129**
# ------Valor aprovado:  1434510.0
# Projeto acima do teto:
# ------Nome: A Escola do Rock
# ------CPF ou CNPJ:  16827643000143
# ------Valor aprovado:  12830083.32
# Projeto acima do teto:
# ------Nome: Janela da História – Avenida Paulista
# ------CPF ou CNPJ:  ***507698**
# ------Valor aprovado:  707484.9
# Projeto acima do teto:
# ------Nome: Restauração, Conservação e Modernização - Edifício e Acervo do MASP
# ------CPF ou CNPJ:  60664745000187
# ------Valor aprovado:  23828582.66
# Projeto acima do teto:
# ------Nome: Maracatum
# ------CPF ou CNPJ:  ***481259**
# ------Valor aprovado:  1495668.38
# 1700
# Projeto acima do teto:
# ------Nome: Egito: Casa da Eternidade (título provisório)
# ------CPF ou CNPJ:  08262392000179
# ------Valor aprovado:  15077838.0
# 1800
# Projeto acima do teto:
# ------Nome: Restauração e readequação arquitetônica do casarão do século XVIII no Largo do Pelourinho, nº 10
# ------CPF ou CNPJ:  30775133000109
# ------Valor aprovado:  10269805.02
# Projeto acima do teto:
# ------Nome: Plano Anual de Atividades do Instituto Porto Seguro 2019
# ------CPF ou CNPJ:  06864650000161
# ------Valor aprovado:  12787990.71
# Projeto acima do teto:
# ------Nome: Produção do CD/DVD:  Edu Farias -  Conquistas - Ao Vivo em Goiânia
# ------CPF ou CNPJ:  ***636049**
# ------Valor aprovado:  705695.25
# 1900
# Projeto acima do teto:
# ------Nome: TAFFINHO Em Busca do Captador Mágico
# ------CPF ou CNPJ:  ***120518**
# ------Valor aprovado:  702954.0
# Projeto acima do teto:
# ------Nome: ÉPIDO O REI
# ------CPF ou CNPJ:  ***526288**
# ------Valor aprovado:  731362.5
# Projeto acima do teto:
# ------Nome: Flores Mágicas A Missão
# ------CPF ou CNPJ:  ***094437**
# ------Valor aprovado:  798781.5
# Projeto acima do teto:
# ------Nome: Animapraça - Edição I
# ------CPF ou CNPJ:  ***401318**
# ------Valor aprovado:  715294.25
# 2000
# ID:  2000
# Nome do projeto:  O HOMEM DA MEIA NOITE
# Área do projeto:  Artes Cênicas
# Total Solicitado: 4959510.00
# Total Aprovado: 4959510.00
# ID:  2001
# Nome do projeto:  Biblioteca Digital Social
# Área do projeto:  Humanidades
# Total Solicitado: 2900150.00
# Total Aprovado: 2900150.00
# ID:  2002
# Nome do projeto:  Restauro Arquitetonico da Extinta RFFSA -Segunda Etapa
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 3344936.50
# Total Aprovado: 3344936.50
# ID:  2003
# Nome do projeto:  Jovens Músicos (6ª Edição)
# Área do projeto:  Música
# Total Solicitado: 919756.31
# Total Aprovado: 919756.31
# ID:  2004
# Nome do projeto:  Zeca e o Mistério dos Irmãos Lumière
# Área do projeto:  Humanidades
# Total Solicitado: 319167.15
# Total Aprovado: 319167.15
# ID:  2005
# Nome do projeto:  Páscoa em Gramado: Arte e Cultura 2019
# Área do projeto:  Artes Cênicas
# Total Solicitado: 2285371.42
# Total Aprovado: 1067971.42
# ID:  2006
# Nome do projeto:  Caravana Cultural
# Área do projeto:  Artes Cênicas
# Total Solicitado: 799503.75
# Total Aprovado: 799503.75
# Projeto acima do teto:
# ------Nome: Recontando Histórias
# ------CPF ou CNPJ:  ***117188**
# ------Valor aprovado:  1367209.8
# ID:  2007
# Nome do projeto:  Recontando Histórias
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1367209.80
# Total Aprovado: 1367209.80
# ID:  2008
# Nome do projeto:  Plano Anual Casa da Memória Italiana 2019
# Área do projeto:  Museus e Memória
# Total Solicitado: 470459.74
# Total Aprovado: 898113.15
# ID:  2009
# Nome do projeto:  Castelo de Cristal
# Área do projeto:  Humanidades
# Total Solicitado: 198508.75
# Total Aprovado: 198508.75
# Projeto acima do teto:
# ------Nome: Mostra Nacional de Teatro NaLona
# ------CPF ou CNPJ:  ***879318**
# ------Valor aprovado:  1150361.19
# ID:  2010
# Nome do projeto:  Mostra Nacional de Teatro NaLona
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1150361.19
# Total Aprovado: 1150361.19
# ID:  2011
# Nome do projeto:  32º FITUB - Festival Internacional de Teatro Universitário de Blumenau
# Área do projeto:  Artes Cênicas
# Total Solicitado: 428947.90
# Total Aprovado: 428947.90
# ID:  2012
# Nome do projeto:  Guia do cavalheiro para se dar bem no amor, e no crime
# Área do projeto:  Artes Cênicas
# Total Solicitado: 7694242.81
# Total Aprovado: 7694242.81
# ID:  2013
# Nome do projeto:  Desfile carnaval de rua de Porto Alegre - carnaval da resistência.
# Área do projeto:  Artes Cênicas
# Total Solicitado: 447370.00
# Total Aprovado: 447370.00
# ID:  2014
# Nome do projeto:  Plano Anual de Atividades do Museu das Minas e do Metal - 2019
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 6074719.19
# Total Aprovado: 6074719.19
# ID:  2015
# Nome do projeto:  Orquestra de Meninas da Ong Assis - 2ª edição
# Área do projeto:  Música
# Total Solicitado: 266744.50
# Total Aprovado: 266744.50
# ID:  2016
# Nome do projeto:  Zion – O Musical
# Área do projeto:  Artes Cênicas
# Total Solicitado: 566998.08
# Total Aprovado: 566998.08
# ID:  2017
# Nome do projeto:  Orquestra Criança Cidadã - Plano Anual de Atividades 2019
# Área do projeto:  Música
# Total Solicitado: 5027604.22
# Total Aprovado: 4990104.22
# ID:  2018
# Nome do projeto:  Projeto Rosa dos Ventos de Música
# Área do projeto:  Música
# Total Solicitado: 856480.78
# Total Aprovado: 856480.78
# ID:  2019
# Nome do projeto:  FARO DE ARTISTA - PLANO ANUAL
# Área do projeto:  Artes Cênicas
# Total Solicitado: 280339.50
# Total Aprovado: 280339.50
# ID:  2020
# Nome do projeto:  Circuito Cultural de Teatro Infantil
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1018580.64
# Total Aprovado: 1018580.64
# ID:  2021
# Nome do projeto:  Envelopes – Testemunhas Postais da História
# Área do projeto:  Humanidades
# Total Solicitado: 524362.41
# Total Aprovado: 489613.41
# ID:  2022
# Nome do projeto:  Projeto Cultural Criança que lê constrói uma sociedade melhor a cada página.
# Área do projeto:  Humanidades
# Total Solicitado: 494861.74
# Total Aprovado: 494861.74
# ID:  2023
# Nome do projeto:  VII FESTIVAL INTERNACIONAL DE MÚSICA SONATA - FRANCISCO BELTRÃO
# Área do projeto:  Música
# Total Solicitado: 213584.32
# Total Aprovado: 213584.32
# ID:  2024
# Nome do projeto:  2ª  Feira do Livro Infantil de Salvador - FLIS
# Área do projeto:  Humanidades
# Total Solicitado: 1169781.76
# Total Aprovado: 1164803.36
# ID:  2025
# Nome do projeto:  Música no Alto Tietê
# Área do projeto:  Música
# Total Solicitado: 417118.48
# Total Aprovado: 417118.48
# ID:  2026
# Nome do projeto:  Caravana Ecoarte
# Área do projeto:  Artes Cênicas
# Total Solicitado: 728974.40
# Total Aprovado: 728974.40
# ID:  2027
# Nome do projeto:  Marien Calixte Jazz Music Festival
# Área do projeto:  Música
# Total Solicitado: 297065.34
# Total Aprovado: 293976.54
# ID:  2028
# Nome do projeto:  Pedra, universo escondido - Denise Milan
# Área do projeto:  Humanidades
# Total Solicitado: 260362.75
# Total Aprovado: 260362.75
# ID:  2029
# Nome do projeto:  PLANO ANUAL DE ATIVIDADES CASA DE CULTURA MÁRIO QUINTANA
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1691014.05
# Total Aprovado: 1691014.05
# ID:  2030
# Nome do projeto:  Mais cultura: Literatura em Bonecos
# Área do projeto:  Artes Cênicas
# Total Solicitado: 132704.00
# Total Aprovado: 132704.00
# ID:  2031
# Nome do projeto:  I FESTIVAL DA VIOLA INSTRUMENTAL DO NORTE DE MG
# Área do projeto:  Música
# Total Solicitado: 253847.55
# Total Aprovado: 253847.55
# ID:  2032
# Nome do projeto:  Os Atrevidos
# Área do projeto:  Música
# Total Solicitado: 675823.50
# Total Aprovado: 675823.50
# ID:  2033
# Nome do projeto:  FESTIVAL DE INVERNO DE CATAGUASES - FIC IN BLUES
# Área do projeto:  Música
# Total Solicitado: 142026.57
# Total Aprovado: 142026.57
# ID:  2034
# Nome do projeto:  Jackson do Pandeiro 100 anos
# Área do projeto:  Música
# Total Solicitado: 681410.07
# Total Aprovado: 681410.07
# ID:  2035
# Nome do projeto:  MUSICAL    JOÃO VITOR E GABRIEL
# Área do projeto:  Música
# Total Solicitado: 197461.00
# Total Aprovado: 197461.00
# ID:  2036
# Nome do projeto:  II CANTA LUIZ
# Área do projeto:  Música
# Total Solicitado: 361307.00
# Total Aprovado: 361307.00
# ID:  2037
# Nome do projeto:  Oficina Nômade Edição Pernambuco
# Área do projeto:  Humanidades
# Total Solicitado: 393750.00
# Total Aprovado: 393750.00
# ID:  2038
# Nome do projeto:  Programação Aventura Teatros 2019
# Área do projeto:  Artes Cênicas
# Total Solicitado: 4984970.00
# Total Aprovado: 4984970.00
# ID:  2039
# Nome do projeto:  Mia Cara 2019
# Área do projeto:  Música
# Total Solicitado: 940720.50
# Total Aprovado: 940720.50
# ID:  2040
# Nome do projeto:  Projeto Estufa - 3ª Edição
# Área do projeto:  Artes Visuais
# Total Solicitado: 2199921.00
# Total Aprovado: 2199921.00
# ID:  2041
# Nome do projeto:  Vitrine Cultural & Gastronômica
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1398654.00
# Total Aprovado: 1370208.00
# ID:  2042
# Nome do projeto:  Cantos Recicla
# Área do projeto:  Humanidades
# Total Solicitado: 812537.50
# Total Aprovado: 812537.50
# ID:  2043
# Nome do projeto:  Projeto de Infraestrutura e Interventivo de Restauração dos Bens Culturais Imóveis e Integrados da Capela de São Francisco Xavier
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 5378501.27
# Total Aprovado: 5378501.27
# ID:  2044
# Nome do projeto:  Programação Cultural
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1465624.16
# Total Aprovado: 1465624.16
# ID:  2045
# Nome do projeto:  FESTIVAL DE ARTES E SUSTENTABILIDADE VILA FLORES
# Área do projeto:  Música
# Total Solicitado: 651032.31
# Total Aprovado: 651032.31
# ID:  2046
# Nome do projeto:  7º FESTIVAL NATIVISTA CANTO DE LUZ E 3ª LAMPARINA DA CANÇÃO GAÚCHA
# Área do projeto:  Música
# Total Solicitado: 53445.13
# Total Aprovado: 53445.13
# ID:  2047
# Nome do projeto:  Festival de Luzes de Florianópolis
# Área do projeto:  Artes Visuais
# Total Solicitado: 681283.68
# Total Aprovado: 681283.68
# ID:  2048
# Nome do projeto:  O FEITIÇO DO SORRISO PERFEITO
# Área do projeto:  Artes Cênicas
# Total Solicitado: 709611.76
# Total Aprovado: 709611.76
# ID:  2049
# Nome do projeto:  Associação Casa Azul - Plano Anual 2019
# Área do projeto:  Humanidades
# Total Solicitado: 5880839.58
# Total Aprovado: 5040843.06
# ID:  2050
# Nome do projeto:  Festival Carijo da Canção Gaúcha 2019
# Área do projeto:  Patrimônio Cultural
# Total Solicitado: 359931.00
# Total Aprovado: 359931.00
# ID:  2051
# Nome do projeto:  Valongo Festival Internacional da Imagem 2019
# Área do projeto:  Artes Visuais
# Total Solicitado: 2098259.57
# Total Aprovado: 2098259.57
# ID:  2052
# Nome do projeto:  HACKTUDO 2019 - Festival de Cultura Digital
# Área do projeto:  Artes Visuais
# Total Solicitado: 1829633.75
# Total Aprovado: 1829633.75
# ID:  2053
# Nome do projeto:  Milagres - Francisco das Chagas
# Área do projeto:  Música
# Total Solicitado: 243100.00
# Total Aprovado: 243100.00
# ID:  2054
# Nome do projeto:  FESTIVAL BRASILEIRO SARAU MUSIC
# Área do projeto:  Música
# Total Solicitado: 86548.96
# Total Aprovado: 86548.96
# ID:  2055
# Nome do projeto:  K&K NA ESTRADA
# Área do projeto:  Música
# Total Solicitado: 403216.00
# Total Aprovado: 403216.00
# Projeto acima do teto:
# ------Nome: DVD E TURNÊ - DON DILLINGER
# ------CPF ou CNPJ:  ***023161**
# ------Valor aprovado:  870952.5
# ID:  2056
# Nome do projeto:  DVD E TURNÊ - DON DILLINGER
# Área do projeto:  Música
# Total Solicitado: 870952.50
# Total Aprovado: 870952.50
# ID:  2057
# Nome do projeto:  CENTRAL ROCK FESTIVAL
# Área do projeto:  Música
# Total Solicitado: 9978.32
# Total Aprovado: 9978.32
# ID:  2058
# Nome do projeto:  Plataforma Asta - Ano I
# Área do projeto:  Humanidades
# Total Solicitado: 1062379.50
# Total Aprovado: 916291.74
# ID:  2059
# Nome do projeto:  Seu Pereira na BR101 - Uma Expedição Musical sobre a Cena Independente
# Área do projeto:  Música
# Total Solicitado: 136125.00
# Total Aprovado: 130725.00
# ID:  2060
# Nome do projeto:  Oficinas na Fundação Cultural
# Área do projeto:  Artes Cênicas
# Total Solicitado: 457870.08
# Total Aprovado: 457870.08
# ID:  2061
# Nome do projeto:  Ilusões
# Área do projeto:  Artes Visuais
# Total Solicitado: 1410700.86
# Total Aprovado: 1410700.86
# ID:  2062
# Nome do projeto:  Teatro Jovem - 25 anos
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1879012.50
# Total Aprovado: 1879012.50
# ID:  2063
# Nome do projeto:  Exposição Mário Fava e a Carretera Panamericana
# Área do projeto:  Artes Visuais
# Total Solicitado: 1038133.80
# Total Aprovado: 1038133.80
# ID:  2064
# Nome do projeto:  Livro A Cor do Rio (nome provisório)
# Área do projeto:  Humanidades
# Total Solicitado: 343580.60
# Total Aprovado: 340335.60
# ID:  2065
# Nome do projeto:  MATRIOSKAS
# Área do projeto:  Artes Cênicas
# Total Solicitado: 769340.00
# Total Aprovado: 769340.00
# ID:  2066
# Nome do projeto:  Djanira, artista do povo (título provisório)
# Área do projeto:  Artes Visuais
# Total Solicitado: 586947.63
# Total Aprovado: 529610.13
# ID:  2067
# Nome do projeto:  ORQUESTRA DE SUCATA NOS CEUS
# Área do projeto:  Música
# Total Solicitado: 499922.50
# Total Aprovado: 499922.50
# ID:  2068
# Nome do projeto:  VAI TER TEATRO NA ESCOLA 2ª EDIÇÃO
# Área do projeto:  Artes Cênicas
# Total Solicitado: 300817.00
# Total Aprovado: 300817.00
# ID:  2069
# Nome do projeto:  Programação Artística no Festival Nacional da Massa – Fenamassa
# Área do projeto:  Artes Cênicas
# Total Solicitado: 486253.66
# Total Aprovado: 486253.66
# ID:  2070
# Nome do projeto:  Hoje Tem Teatro
# Área do projeto:  Artes Cênicas
# Total Solicitado: 592012.50
# Total Aprovado: 592012.50
# ID:  2071
# Nome do projeto:  Casa do Beco - Plano anual 2019 - Programação Cultural a serviço da Comunidade
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1929730.00
# Total Aprovado: 1887440.00
# ID:  2072
# Nome do projeto:  PLANO ANUAL DE ATIVIDADES CULTURAIS DA CASA ESPIRITA DA SOPA ADOLFO FRITZ 2019
# Área do projeto:  Artes Cênicas
# Total Solicitado: 389873.00
# Total Aprovado: 389873.00
# ID:  2073
# Nome do projeto:  Livro Realização
# Área do projeto:  Humanidades
# Total Solicitado: 225054.50
# Total Aprovado: 225054.50
# ID:  2074
# Nome do projeto:  100 anos de Meyer Filho: Distâncias Mínimas
# Área do projeto:  Artes Visuais
# Total Solicitado: 490362.34
# Total Aprovado: 485612.34
# ID:  2075
# Nome do projeto:  ANÁLIA FRANCO - UM CANDEEIRO SOBRE O ALQUEIRE
# Área do projeto:  Artes Cênicas
# Total Solicitado: 696676.96
# Total Aprovado: 696676.96
# ID:  2076
# Nome do projeto:  Circuito TIC
# Área do projeto:  Artes Cênicas
# Total Solicitado: 404001.68
# Total Aprovado: 404001.68
# ID:  2077
# Nome do projeto:  AMA - VAMOS CHOVER!
# Área do projeto:  Artes Cênicas
# Total Solicitado: 532263.60
# Total Aprovado: 532263.60
# ID:  2078
# Nome do projeto:  Mario Penna - Uma História Feita por Você
# Área do projeto:  Humanidades
# Total Solicitado: 422643.75
# Total Aprovado: 422643.75
# ID:  2079
# Nome do projeto:  Circuito Cultural Contagem – 2019
# Área do projeto:  Artes Cênicas
# Total Solicitado: 371506.12
# Total Aprovado: 371870.40
# ID:  2080
# Nome do projeto:  Armatrux em Cena: Manutenção e Circulação
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1509401.92
# Total Aprovado: 1494067.90
# ID:  2081
# Nome do projeto:  Oficinas Culturais
# Área do projeto:  Artes Cênicas
# Total Solicitado: 72702.70
# Total Aprovado: 72702.70
# ID:  2082
# Nome do projeto:  “A CASA DE HUNDERTWASSER”
# Área do projeto:  Artes Cênicas
# Total Solicitado: 435473.81
# Total Aprovado: 435473.81
# ID:  2083
# Nome do projeto:  Pesquisa Científica Brasileira: O ontem, o hoje e o amanhã
# Área do projeto:  Artes Visuais
# Total Solicitado: 686717.60
# Total Aprovado: 686717.60
# ID:  2084
# Nome do projeto:  CIRCUITO NATALINO
# Área do projeto:  Artes Cênicas
# Total Solicitado: 687006.56
# Total Aprovado: 687006.56
# ID:  2085
# Nome do projeto:  CIDADES INTELIGENTES
# Área do projeto:  Artes Visuais
# Total Solicitado: 992797.70
# Total Aprovado: 992797.70
# ID:  2086
# Nome do projeto:  Sabores do Brasil
# Área do projeto:  Humanidades
# Total Solicitado: 782027.58
# Total Aprovado: 782027.58
# ID:  2087
# Nome do projeto:  FILHOS DE SUCENA
# Área do projeto:  Humanidades
# Total Solicitado: 135990.80
# Total Aprovado: 134917.00
# ID:  2088
# Nome do projeto:  Hammond Grooves & artistas PE
# Área do projeto:  Música
# Total Solicitado: 498894.19
# Total Aprovado: 498894.19
# ID:  2089
# Nome do projeto:  Ilumina Zona Oeste
# Área do projeto:  Artes Cênicas
# Total Solicitado: 288966.15
# Total Aprovado: 288966.15
# ID:  2090
# Nome do projeto:  Ana Maria Dias - Obras (título provisório)
# Área do projeto:  Humanidades
# Total Solicitado: 210298.00
# Total Aprovado: 210298.00
# ID:  2091
# Nome do projeto:  Encontro de Orquestras
# Área do projeto:  Música
# Total Solicitado: 78712.00
# Total Aprovado: 78712.00
# ID:  2092
# Nome do projeto:  Medicando alegria
# Área do projeto:  Artes Cênicas
# Total Solicitado: 397228.00
# Total Aprovado: 397228.00
# ID:  2093
# Nome do projeto:  CONEXÕES
# Área do projeto:  Humanidades
# Total Solicitado: 225673.36
# Total Aprovado: 225673.36
# ID:  2094
# Nome do projeto:  TEM UM RIO NA BIBLIOTECA
# Área do projeto:  Artes Cênicas
# Total Solicitado: 1131222.82
# Total Aprovado: 1131222.82
# ID:  2095
# Nome do projeto:  PLANO ANUAL MUSICA SINFÔNICA PARA TODOS
# Área do projeto:  Música
# Total Solicitado: 2835588.75
# Total Aprovado: 2835588.75
# ID:  2096
# Nome do projeto:    Circulação  Apareceu A Margarida
# Área do projeto:  Artes Cênicas
# Total Solicitado: 152641.50
# Total Aprovado: 152641.50
# ID:  2097
# Nome do projeto:  Fábrica de Graffiti - Feira de Santana
# Área do projeto:  Artes Visuais
# Total Solicitado: 287779.80
# Total Aprovado: 415742.25
# ID:  2098
# Nome do projeto:  Exposição Uma Casa Mil Olhares  4ª Edição
# Área do projeto:  Artes Visuais
# Total Solicitado: 1559992.84
# Total Aprovado: 1559992.84
# ID:  2099
# Nome do projeto:  Coleção Monteiro Lobato
# Área do projeto:  Humanidades
# Total Solicitado: 1723837.50
# Total Aprovado: 1723837.50
# 2100
# Projeto acima do teto:
# ------Nome: De Pequeno a Grande Otelo
# ------CPF ou CNPJ:  ***534066**
# ------Valor aprovado:  1265220.0
# Projeto acima do teto:
# ------Nome: Plano Bienal de Atividades Culturais do PTI
# ------CPF ou CNPJ:  07769688000118
# ------Valor aprovado:  10545120.0
# Projeto acima do teto:
# ------Nome: Viola Cabocla, um tributo a Tião Carreiro
# ------CPF ou CNPJ:  ***008001**
# ------Valor aprovado:  704516.0
# Projeto acima do teto:
# ------Nome: Floripa Jazz Festival 2019
# ------CPF ou CNPJ:  ***507289**
# ------Valor aprovado:  1430895.38
# Projeto acima do teto:
# ------Nome: Dress Tents
# ------CPF ou CNPJ:  ***909068**
# ------Valor aprovado:  943551.36
# 2200
# Projeto acima do teto:
# ------Nome: O PEQUENO PRINCIPE
# ------CPF ou CNPJ:  07031361000144
# ------Valor aprovado:  10209133.08
# Projeto acima do teto:
# ------Nome: PROJETO MÚSICA NAS ESCOLAS DE BARRA MANSA - A ARTE DE EDUCAR ATRAVÉS DA MÚSICA - PLANO BIENAL 2019/2020
# ------CPF ou CNPJ:  17747426000106
# ------Valor aprovado:  18082945.17
# Projeto acima do teto:
# ------Nome: EQUUS
# ------CPF ou CNPJ:  ***434388**
# ------Valor aprovado:  1219778.34
# Projeto acima do teto:
# ------Nome: SOS PANTANAL
# ------CPF ou CNPJ:  ***966171**
# ------Valor aprovado:  700088.4
# 2300
# Projeto acima do teto:
# ------Nome: Espetáculo O Assalto
# ------CPF ou CNPJ:  ***573548**
# ------Valor aprovado:  1085962.96
# Projeto acima do teto:
# ------Nome: Plano Anual de Atividades e Temporada 2019 - Orquestra Sinfônica Brasileira
# ------CPF ou CNPJ:  33659327000129
# ------Valor aprovado:  22390178.5
# Projeto acima do teto:
# ------Nome: CHICAGO - O MUSICAL
# ------CPF ou CNPJ:  15464374000216
# ------Valor aprovado:  16645389.5
# Projeto acima do teto:
# ------Nome: Produção do CD/DVD Jalles & Dyego - Ao vivo
# ------CPF ou CNPJ:  ***742321**
# ------Valor aprovado:  706622.52
# Projeto acima do teto:
# ------Nome: RESTAURO E REFORMA DAS EDIFICAÇÕES E ENTORNOS DA ESCOLA DE ARTES VISUAIS DO PARQUE LAGE – SEGUNDO MODULO – OBRAS
# ------CPF ou CNPJ:  29279924000150
# ------Valor aprovado:  42624603.4
# 2400
# Projeto acima do teto:
# ------Nome: NATAL ILUMINADO DE GUARULHOS
# ------CPF ou CNPJ:  11965350000109
# ------Valor aprovado:  10985687.25
# Projeto acima do teto:
# ------Nome: Arte e Diversidade Brasileira
# ------CPF ou CNPJ:  ***702528**
# ------Valor aprovado:  713632.66
# Projeto acima do teto:
# ------Nome: Orquestra Filarmônica de Minas Gerais – Plano Anual 2019
# ------CPF ou CNPJ:  07837375000150
# ------Valor aprovado:  20081317.52
# Projeto acima do teto:
# ------Nome: GRUPO CORPO 2019
# ------CPF ou CNPJ:  07224449000182
# ------Valor aprovado:  13127658.0
# Projeto acima do teto:
# ------Nome: Plano Anual de Atividades MAM Rio 2019
# ------CPF ou CNPJ:  00367651000114
# ------Valor aprovado:  11114983.69
# 2500
# Projeto acima do teto:
# ------Nome: In.Art
# ------CPF ou CNPJ:  ***654201**
# ------Valor aprovado:  1042556.08
# Projeto acima do teto:
# ------Nome:  PLANO ANUAL UNIBES CULTURAL - 2019
# ------CPF ou CNPJ:  51582658000190
# ------Valor aprovado:  15220344.17
# Projeto acima do teto:
# ------Nome: GRAVAÇÃO E TURNÊ DE DIVULGAÇÃO DO DVD DA BANDA GAROTOS DO PARÁ.
# ------CPF ou CNPJ:  ***397381**
# ------Valor aprovado:  1199611.18
# Projeto acima do teto:
# ------Nome: MOSTRA SEU SOM CONFRADES
# ------CPF ou CNPJ:  ***593416**
# ------Valor aprovado:  1032098.96
# Projeto acima do teto:
# ------Nome: ARCA - Gestão do Acervo do Centro de Memória da Arquitetura e Engenharia Brasileira
# ------CPF ou CNPJ:  ***209928**
# ------Valor aprovado:  783687.83
# Projeto acima do teto:
# ------Nome: PROJETO ANUAL MON 2019
# ------CPF ou CNPJ:  05695855000106
# ------Valor aprovado:  10353817.45
# Projeto acima do teto:
# ------Nome: Theatro Municipal de São Paulo - Plano Anual 2019
# ------CPF ou CNPJ:  02612590000481
# ------Valor aprovado:  18765705.29
# Projeto acima do teto:
# ------Nome: IL BALLETTO – A DANÇA SOB OUTROS EIXOS
# ------CPF ou CNPJ:  ***182628**
# ------Valor aprovado:  802494.0
# Projeto acima do teto:
# ------Nome: PAUL KLEE - EQUILÍBRIO INSTÁVEL
# ------CPF ou CNPJ:  46874756000160
# ------Valor aprovado:  12353062.06
# 2600
# Projeto acima do teto:
# ------Nome: Plano Anual – Museu do Amanhã 2019
# ------CPF ou CNPJ:  04393475000499
# ------Valor aprovado:  23764333.45
# Projeto acima do teto:
# ------Nome: CORAÇÃO DE VIDRO
# ------CPF ou CNPJ:  ***616398**
# ------Valor aprovado:  703842.5
# Projeto acima do teto:
# ------Nome: Moletom Vermelho
# ------CPF ou CNPJ:  ***411129**
# ------Valor aprovado:  706259.8
# Projeto acima do teto:
# ------Nome: AOI
# ------CPF ou CNPJ:  ***900528**
# ------Valor aprovado:  855846.8
# 2700
# Projeto acima do teto:
# ------Nome: CAMERATA DE CONCERTO - série de concertos 2019
# ------CPF ou CNPJ:  ***203288**
# ------Valor aprovado:  965212.2
# Projeto acima do teto:
# ------Nome: Reveillon das Águas
# ------CPF ou CNPJ:  ***867200**
# ------Valor aprovado:  1049797.0
# Projeto acima do teto:
# ------Nome: Mostra de Festas Tradicionais do RS
# ------CPF ou CNPJ:  ***249810**
# ------Valor aprovado:  1442324.14
# Projeto acima do teto:
# ------Nome: Segunda Encenação da Paixão de Cristo
# ------CPF ou CNPJ:  ***608517**
# ------Valor aprovado:  1231401.5
# 2800
# Projeto acima do teto:
# ------Nome: A Maior Palavra do Mundo
# ------CPF ou CNPJ:  ***634478**
# ------Valor aprovado:  1489071.2
# Projeto acima do teto:
# ------Nome: João, Joãozinho, Joãozito – O menino Encantado.
# ------CPF ou CNPJ:  ***675178**
# ------Valor aprovado:  762144.0
# Projeto acima do teto:
# ------Nome: Plano Anual de atividades MIS e Paço das Artes 2019
# ------CPF ou CNPJ:  71929889000134
# ------Valor aprovado:  10276016.0
# Projeto acima do teto:
# ------Nome: Museu Judaico de São Paulo - Plano Bianual 2019 / 2020
# ------CPF ou CNPJ:  04414533000170
# ------Valor aprovado:  18713623.53
# Projeto acima do teto:
# ------Nome: Plano Anual de Atividades e Manutenção 2019 - Instituto Inhotim
# ------CPF ou CNPJ:  05422243000131
# ------Valor aprovado:  29556828.33
# Projeto acima do teto:
# ------Nome: 12ª Bienal de Artes Visuais do Mercosul - Plano Plurianual
# ------CPF ou CNPJ:  01546913000170
# ------Valor aprovado:  13304262.02
# Projeto acima do teto:
# ------Nome: Réveillon de Copacabana 2019
# ------CPF ou CNPJ:  07902231000130
# ------Valor aprovado:  20138866.75
# 2900
# Projeto acima do teto:
# ------Nome: Mockingbird
# ------CPF ou CNPJ:  ***398448**
# ------Valor aprovado:  907012.32
# Projeto acima do teto:
# ------Nome: PLANO ANUAL CASA FIAT DE CULTURA 2019
# ------CPF ou CNPJ:  02094828000262
# ------Valor aprovado:  17011804.3
# Projeto acima do teto:
# ------Nome: Plano Anual 2019 da Pinacoteca de São Paulo
# ------CPF ou CNPJ:  96290846000182
# ------Valor aprovado:  16673737.88
# Projeto acima do teto:
# ------Nome: Conexão Gospel
# ------CPF ou CNPJ:  ***108376**
# ------Valor aprovado:  955261.02
# Projeto acima do teto:
# ------Nome: Fórum Mundial Niemeyer
# ------CPF ou CNPJ:  ***773217**
# ------Valor aprovado:  1102252.05
# Projeto acima do teto:
# ------Nome: Plano Anual de Atividades Osesp 2019
# ------CPF ou CNPJ:  07495643000100
# ------Valor aprovado:  31313668.07
# Projeto acima do teto:
# ------Nome: Museu de Arte do Rio – Plano Anual 2019
# ------CPF ou CNPJ:  02612590000210
# ------Valor aprovado:  19838991.7
# Projeto acima do teto:
# ------Nome: DE NOITE TODO GATO É PARDO
# ------CPF ou CNPJ:  ***122688**
# ------Valor aprovado:  708715.58
# Projeto acima do teto:
# ------Nome: Natal Luz de Ouro Preto
# ------CPF ou CNPJ:  ***322576**
# ------Valor aprovado:  1482664.0
# 3000
# Projeto acima do teto:
# ------Nome: MASP 2019 (Plano Anual)
# ------CPF ou CNPJ:  60664745000187
# ------Valor aprovado:  28788912.19
# Projeto acima do teto:
# ------Nome: FRITZ PLAUMANN - A Imortalização de sua obra em livro, biblioteca e museu virtual
# ------CPF ou CNPJ:  ***131769**
# ------Valor aprovado:  995584.5
# Projeto acima do teto:
# ------Nome: Humor em Dose Dupla
# ------CPF ou CNPJ:  ***373918**
# ------Valor aprovado:  853701.25
# Projeto acima do teto:
# ------Nome: Ilumina Festival 2019
# ------CPF ou CNPJ:  ***815338**
# ...
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14024
# Nome do projeto:  Manuela Bezerra Gouveia de Andrade
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14025
# Nome do projeto:  Renato Coelho Pannacci
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14026
# Nome do projeto:  Roberta de camargo
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14027
# Nome do projeto:  Credenciamento de jurados 2017
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14028
# Nome do projeto:  Matheus Medeiros de Sousa
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14029
# Nome do projeto:  Poemas de Ferreira Gullar
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14030
# Nome do projeto:  Pedro Bezerra da Costa
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14031
# Nome do projeto:  Camila Souza Tomaz
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14032
# Nome do projeto:  PROFESSORA DOUTORA CRISTIANE PIMENTEL NEDER.
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14033
# Nome do projeto:  CREDENCIAMENTO DE JURADOS EM AUDIOVISUAL
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14034
# Nome do projeto:  POLIANA JAQUELINE DOS REIS MOREIRA
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14035
# Nome do projeto:  Melanie Dimantas
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14036
# Nome do projeto:  MARIA DAS GRAÇAS SOUSA COUTINHO (GRAÇA COUTINHO)
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14037
# Nome do projeto:  ANNA CAROLINA FARIA LÍRIO
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14038
# Nome do projeto:  Diretora-Roteirista
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14039
# Nome do projeto:  Raul Lemos Arthuso
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14040
# Nome do projeto:  Marcelle Darrieux
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14041
# Nome do projeto:  Caroline Natale Melquiades Rooke
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14042
# Nome do projeto:  Fabiana de Oliveira Assis - Jurada em Produção Audiovisual / Novas Mídias
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14043
# Nome do projeto:  Thais Botrel Reis
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14044
# Nome do projeto:  Raphael Irerê
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14045
# Nome do projeto:  EDITAL DE CREDENCIAMENTO DE JURADO AUDIOVISUAL
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14046
# Nome do projeto:  Marcelo Braga de Freitas
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14047
# Nome do projeto:  Alex Santos Barbosa
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14048
# Nome do projeto:  Parada de Cinema
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14049
# Nome do projeto:  Carla Gallo
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14050
# Nome do projeto:  Ana Paula Sousa
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14051
# Nome do projeto:  André Huchi Dib
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14052
# Nome do projeto:  O universo de Ferreira Gullar
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14053
# Nome do projeto:  Ferreira Gullar / Gullistening - Uma iniciativa para deficientes visuais
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14054
# Nome do projeto:  CREDENCIAMENTO DE JURADOS EM AUDIOVISUAL
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14055
# Nome do projeto:  Gullar Run
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14056
# Nome do projeto:  Thayná Stephany de Almeida Torella
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14057
# Nome do projeto:  Conectados com Ferreira Gullar
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14058
# Nome do projeto:  Daniel de Queiroz Soares
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14059
# Nome do projeto:  Leonardo Mecchi
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14060
# Nome do projeto:  CREDENCIAMENTO DE JURADOS EM AUDIOVISUAL - Edital 01 / 2017
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14061
# Nome do projeto:  Turvo: jogo da memória como instrumento para formação literária lúdica
# Área do projeto:  Artes Integradas
# Total Solicitado: 0.00
# Total Aprovado: 0.00
# ID:  14062
# Nome do projeto:  Linhas do Tempo
# Área do projeto:  Audiovisual
# Total Solicitado: 886057.50
# Total Aprovado: 886057.50
# ID:  14063
# Nome do projeto:  Alegria Virtual - Cultura que Liberta!
# Área do projeto:  Audiovisual
# Total Solicitado: 195937.46
# Total Aprovado: 195937.46
# ID:  14064
# Nome do projeto:  Homofobia: o preconceito pode matar!
# Área do projeto:  Audiovisual
# Total Solicitado: 284735.00
# Total Aprovado: 284735.00
# ID:  14065
# Nome do projeto:  FBL - Comidas de Rua
# Área do projeto:  Audiovisual
# Total Solicitado: 199638.00
# Total Aprovado: 199638.00
# ID:  14066
# Nome do projeto:  50º Festival de Brasília do Cinema Brasileiro
# Área do projeto:  Audiovisual
# Total Solicitado: 4357352.27
# Total Aprovado: 971596.00
# ID:  14067
# Nome do projeto:  Gema  - 2ª Temporada
# Área do projeto:  Audiovisual
# Total Solicitado: 404717.17
# Total Aprovado: 404717.17
# ID:  14068
# Nome do projeto:  Um teto sobre nós
# Área do projeto:  Artes Cênicas
# Total Solicitado: 301590.88
# Total Aprovado: 301590.88
# ID:  14069
# Nome do projeto:  9ª Temporada de Música Clássica de Sorocaba
# Área do projeto:  Música
# Total Solicitado: 763759.15
# Total Aprovado: 763759.15
# ID:  14070
# Nome do projeto:  MITOS INDÍGENAS EM TRAVESSIA
# Área do projeto:  Audiovisual
# Total Solicitado: 649035.97
# Total Aprovado: 649035.97
# ID:  14071
# Nome do projeto:  TALENTOS DE OURO  2018 - CONTINUIDADE...
# Área do projeto:  Música
# Total Solicitado: 287251.20
# Total Aprovado: 287251.20
# ID:  14072
# Nome do projeto:  Rio Jazz Instrumental - 3ª Edição
# Área do projeto:  Música
# Total Solicitado: 559522.10
# Total Aprovado: 559522.10
# ID:  14073
# Nome do projeto:  Ceará Natal de Luz 2017
# Área do projeto:  Música
# Total Solicitado: 1599411.01
# Total Aprovado: 1558161.01
# ID:  14074
# Nome do projeto:  O ULTIMO CAPÍTULO 2017
# Área do projeto:  Artes Cênicas
# Total Solicitado: 474208.60
# Total Aprovado: 496437.53
# ID:  14075
# Nome do projeto:  Desfile Temático 2017 - Espetáculo: Os Idealistas da Revolução Farroupilha e os 70 Anos do Acendimento da Chama Crioula
# Área do projeto:  Artes Cênicas
# Total Solicitado: 865504.70
# Total Aprovado: 661973.70
# ID:  14076
# Nome do projeto:  AÉREA
# Área do projeto:  Artes Cênicas
# Total Solicitado: 199665.00
# Total Aprovado: 199665.00
# ID:  14077
# Nome do projeto:  Tocata - Homenagem a Tom Jobim - Ano 2017
# Área do projeto:  Música
# Total Solicitado: 87558.25
# Total Aprovado: 79558.25
# ID:  14078
# Nome do projeto:  Palhiare
# Área do projeto:  Artes Cênicas
# Total Solicitado: 309736.85
# Total Aprovado: 271636.85
# ID:  14079
# Nome do projeto:  Projeto Viramundo - Música aos cuidados da Saúde
# Área do projeto:  Música
# Total Solicitado: 199811.10
# Total Aprovado: 199811.10
# ID:  14080
# Nome do projeto:   Oficinas de música gratuitas  no Centro Cultural de Integração das Artes
# Área do projeto:  Música
# Total Solicitado: 173414.93
# Total Aprovado: 168521.18
# ID:  14081
# Nome do projeto:  TURNÊ VOLTAR
# Área do projeto:  Música
# Total Solicitado: 196765.00
# Total Aprovado: 196765.00
# ID:  14082
# Nome do projeto:  Plano Anual de Atividades Cia. Minaz 2018
# Área do projeto:  Música
# Total Solicitado: 2718602.00
# Total Aprovado: 2715689.81
# ID:  14083
# Nome do projeto:  Além da Imaginação
# Área do projeto:  Humanidades
# Total Solicitado: 199810.00
# Total Aprovado: 199810.00
# ID:  14084
# Nome do projeto:  20 anos Depois da Chuva
# Área do projeto:  Artes Cênicas
# Total Solicitado: 147572.38
# Total Aprovado: 147572.38
# ID:  14085
# Nome do projeto:  188º Kerb de São Miguel
# Área do projeto:  Música
# Total Solicitado: 405821.50
# Total Aprovado: 199621.50
# ID:  14086
# Nome do projeto:  Comediologia
# Área do projeto:  Artes Cênicas
# Total Solicitado: 209637.36
# Total Aprovado: 209637.36
# ID:  14087
# Nome do projeto:  11ª Bienal de Artes Visuais do Mercosul
# Área do projeto:  Artes Visuais
# Total Solicitado: 6929288.20
# Total Aprovado: 4885330.22
# ID:  14088
# Nome do projeto:  Weihnachtsfest - Festa de Natal  em Pomerode
# Área do projeto:  Artes Cênicas
# Total Solicitado: 230310.00
# Total Aprovado: 230310.00
# ID:  14089
# Nome do projeto:  63ª Feira do Livro de Porto Alegre
# Área do projeto:  Humanidades
# Total Solicitado: 2887520.35
# Total Aprovado: 1431678.25
# ID:  14090
# Nome do projeto:  MUSICA ENCANTADA 3
# Área do projeto:  Música
# Total Solicitado: 1294191.71
# Total Aprovado: 1262747.00
# ID:  14091
# Nome do projeto:  Projeto - COPRO E SOM
# Área do projeto:  Artes Cênicas
# Total Solicitado: 372898.90
# Total Aprovado: 370898.90
# ID:  14092
# Nome do projeto:  Gravação do CD Vanessa Dias Costa
# Área do projeto:  Música
# Total Solicitado: 197200.00
# Total Aprovado: 197200.00
# ID:  14093
# Nome do projeto:  XV Encontro Brasileiro de Coros Universitários e IX Encantar – Encontro Municipal de Coros Edição Especial 100 anos de Chapecó
# Área do projeto:  Música
# Total Solicitado: 232120.35
# Total Aprovado: 232120.35
# ID:  14094
# Nome do projeto:  LIVRO “TERRA”, DE EMMANUELLE BERNARD
# Área do projeto:  Humanidades
# Total Solicitado: 594159.25
# Total Aprovado: 594159.25
# ID:  14095
# Nome do projeto:  Encontro de Orquestras de Bom Retiro do Sul
# Área do projeto:  Música
# Total Solicitado: 672602.80
# Total Aprovado: 672602.80
# ID:  14096
# Nome do projeto:  Nos Balaios do Seu Zé
# Área do projeto:  Artes Cênicas
# Total Solicitado: 990515.19
# Total Aprovado: 990515.19
# ID:  14097
# Nome do projeto:  II Programa de Exposições Temporárias da Galeria de Arte do Centro Cultural Minas Tênis
# Área do projeto:  Artes Visuais
# Total Solicitado: 1521282.40
# Total Aprovado: 1491282.40
# ID:  14098
# Nome do projeto:  Amigas Pero No Mucho - 10 anos
# Área do projeto:  Artes Cênicas
# Total Solicitado: 717721.00
# Total Aprovado: 656073.00
# ID:  14099
# Nome do projeto:  PIRACICABA, QUE EU ADORO TANTO!
# Área do projeto:  Artes Cênicas
# Total Solicitado: 224715.00
# Total Aprovado: 209715.00
# 14100
# 14200
# 14300
# Projeto acima do teto:
# ------Nome: SÃO JOÃO DE CARUARU CULTURAL
# ------CPF ou CNPJ:  01374871000138
# ------Valor aprovado:  10316564.57
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# Projeto acima do teto:
# ------Nome: Conservação Emergencial dos Edifícios do Pátio Ferroviário de Paranapiacaba
# ------CPF ou CNPJ:  49731466000156
# ------Valor aprovado:  18150991.67
# 15300
# 15400
# 15500
# Projeto acima do teto:
# ------Nome: OPEN AIR 2017
# ------CPF ou CNPJ:  05320143000102
# ------Valor aprovado:  10070832.0
# 15600
# 15700
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-d1c7e14901c2> in <module>()
#       1 for x in range(0,tot,100):
#       2     print(x)
# ----> 3     res = requests.get(url+str(x)+url2)
#       4     res = json.loads(res.content.decode('utf-8'))
#       5     proj = res['_embedded']['projetos']
#
# ~/.local/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/.local/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print("Total solicitado: %.2f" %totalSolicitado)
print("Total Aprovado: %.2f" %totalAprovado)

invQuantAno = []
invAno = []
for x in reversed(quantAno):
    invQuantAno.append(x)

for x in reversed(anos):
    invAno.append(x)

print(" ------ ")
display(Markdown("""
## Projeto relacionados ao carnaval 2019: {carnaval}
## Valor aprovado para projetos do carnaval 2019: {totCarnaval} de reais
""".format(carnaval=carnaval, totCarnaval=totCarnaval)))
print(" ------ ")
print("Quantidade de projetos solicitados com valor R$0: ",projZero)
print(" ------ ")
print("Considerando teto de R$10.000.000,00 para empresas e R$700.000,00 para pessoas físicas")
print("Quantidade de valores aprovados acima do teto: ",acimaTeto)
print(" ------ ")

plt.figure(figsize=(10,7))
plt.ylabel('Quantidade de projetos')
plt.bar(tipos,quantTipos,width=0.5, color='yellow')
plt.tick_params(length=3,labelsize=8,colors='r',
               grid_color='r', grid_alpha=0.5)
plt.show()
for x in range(len(tipos)):
    print(tipos[x]," : ",quantTipos[x])

plt.plot(invAno,invQuantAno)
plt.ylabel('Valor por ano em BILHÕES')
plt.xlabel('Ano')
plt.show()
print("Ano : Valor Aprovado")
for x in range(len(invQuantAno)):
    print(invAno[x],": R$ %.2f" %invQuantAno[x])
# Out:
# Total solicitado: 13271442533.00
# Total Aprovado: 12346586712.22
#  ------
# ## Projeto relacionados ao carnaval 2019: 39
# ## Valor aprovado para projetos do carnaval 2019: 77596169.76 de reais
#  ------
# Quantidade de projetos solicitados com valor R$0:  10941
#  ------
# Considerando teto de R$10.000.000,00 para empresas e R$700.000,00 para pessoas físicas
# Quantidade de valores aprovados acima do teto:  248
#  ------
# Artes Visuais  :  1037
# Artes Cênicas  :  3894
# Humanidades  :  1607
# Música  :  2955
# Patrimônio Cultural  :  428
# Museus e Memória  :  110
# Audiovisual  :  912
# Artes Integradas  :  4757
# Ano : Valor Aprovado
# 16 : R$ 64439243.77
# 17 : R$ 5336147359.61
# 18 : R$ 6545682066.52
# 19 : R$ 400318042.32
